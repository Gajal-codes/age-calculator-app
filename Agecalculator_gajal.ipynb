# %%
from datetime import date

def calculate_age():
    name = input("👋 What's your name? ")
    birth_year = int(input("📅 Enter your birth year: "))
    current_year = date.today().year
    age = current_year - birth_year
    print(f"\n🎉 {name}, you are {age} years old in {current_year}!")

calculate_age()
# Out:
# 👋 What's your name? Gajal sharma
# 📅 Enter your birth year: 2007
#
# 🎉 Gajal sharma , you are 18 years old in 2025!

# %% [markdown]
# 📝 Project: Age Calculator
# 👩‍💻 Created by: Gajal Sharma
# 📆 Date: 28 June 2025
# 🔤 Language: Python
# 🧠 Modules Used: datetime
# ✅ Status: Completed
